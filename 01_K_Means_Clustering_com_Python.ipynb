# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelodepaoli/17_K-means_clustering/blob/main/01_K_Means_Clustering_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K-Means Clustering com Python
#
# O K-Means Clustering é um algoritmo de aprendizado não supervisionado que tenta agrupar dados com base em sua semelhança. O aprendizado não supervisionado significa que não há resultado a ser previsto e o algoritmo apenas tenta encontrar padrões nos dados. No K-Means Clustering, temos que especificar o número de clusters em que queremos que os dados sejam agrupados. O algoritmo atribui aleatoriamente cada observação a um cluster e encontra o centroide de cada cluster. Em seguida, o algoritmo itera através de duas etapas:
#
# 1) Reatribuir pontos de dados ao cluster cujo centroide está mais próximo.
#
# 2) Calcular o novo centroide de cada cluster.
#
# Essas duas etapas são repetidas até que a variação dentro do cluster não possa mais ser reduzida. A variação dentro do cluster é calculada como a soma da distância euclidiana entre os pontos de dados e os respectivos centróides.

# %% [markdown]
# ## Importar Bibliotecas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Criando Alguns Dados

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)

# %% [markdown]
# ## Visualizando os dados

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %% [markdown]
# ## Criando os Clusters

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.46941837, -6.56081545],
#        [-0.0123077 ,  2.13407664],
#        [-4.13591321,  7.95389851],
#        [ 3.71749226,  7.01388735]])

# %%
kmeans.labels_
# Out:
# array([2, 3, 1, 3, 3, 0, 3, 1, 3, 1, 2, 1, 3, 3, 2, 1, 3, 1, 0, 2, 0, 1,
#        1, 0, 2, 0, 0, 1, 3, 3, 2, 0, 3, 1, 1, 2, 0, 0, 0, 1, 0, 2, 2, 2,
#        1, 3, 2, 1, 0, 1, 1, 2, 3, 1, 0, 2, 1, 1, 2, 3, 0, 3, 0, 2, 3, 1,
#        0, 3, 3, 0, 3, 1, 0, 1, 0, 3, 3, 1, 2, 1, 1, 0, 3, 0, 1, 1, 1, 2,
#        1, 0, 0, 0, 0, 1, 1, 0, 3, 2, 0, 3, 1, 0, 1, 1, 3, 1, 0, 3, 0, 0,
#        3, 2, 2, 3, 0, 3, 2, 2, 3, 2, 1, 2, 1, 2, 1, 3, 2, 1, 0, 2, 2, 2,
#        1, 0, 0, 2, 3, 2, 3, 1, 0, 3, 0, 2, 2, 3, 1, 0, 2, 2, 2, 2, 1, 3,
#        1, 2, 3, 3, 3, 1, 3, 1, 1, 2, 0, 2, 1, 3, 2, 1, 3, 1, 2, 3, 1, 2,
#        3, 3, 0, 3, 2, 0, 0, 2, 0, 0, 0, 0, 0, 1, 0, 3, 3, 2, 0, 1, 3, 3,
#        0, 1], dtype=int32)

# %%
f, (ax1, ax2) = plt.subplots(1,2,sharey=True, figsize=(10,6))
ax1.set_title('K_Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# As cores não tem significado em referência entre os dois gráficos.
